# %%
#import all libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# %matplotlib inline

sns.set(style='whitegrid')

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#import dataset
df=pd.read_csv(r"C:\Users\HP\OneDrive\FSDS & Gen AI\28th - Seaborn, Eda Practicle\28th - Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#shape of dataset
df.shape
# Out:
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.dtypes  #datatypes of columns
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# <!-- -age=age in years
# -sex=11:male, 0:female
# -cp=chest pain type
# -trestbps=resting blood pressure
# -chol=serum cholestrol
# -fbs=fasting blood sugar 1:true,0:false
# -restecg=resting electrocardiographic results
# -thalach=maximun heart rate achieved
# -exang=exercise induced angina 1:yes, 0:no
# -oldpeak=ST depression induced by exercise relative to rest
# -slope=slope of peak exercise ST segment
# -ca=no. of major vessels(0-3) colored by flourosopy
# -thal =3:normal, 6:fixed defect, 7:reversable defect
# -target=1 or 0 -->

# %%
df.describe()  #statistical properties
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.describe(include='all')     #statistical properties of all variables
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# to view statistical properties of character variable: df.describe(include=['object'])

# %%
df.columns  #columns of dataset
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # Analysis of target variable
# - 0 refers to absence of heart disease
# - 1 refers to presence of heart disease

# %%
df['target'].nunique()  # there are 2 unique values in target variable
# Out:
# 2

# %%
df['target'].unique()  # view unique values
# Out:
# array([1, 0], dtype=int64)

# %%
df['target'].value_counts() #counts no. of values
# There are 165 patients suffering from heart disease
# There are 138 patients who do not have any heart disease
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='target',data=df)
plt.show()

#graph shows that 138 patients do not have any heart disease 
#165 patients are suffering from heart disease

# %%
df.groupby('sex')['target'].value_counts()
#sex: 0 for female and 1 for male
#target: 0 for absence and 1 for presence of disease
#out of 96 females: 72 have heart disease & 24 do not have heart disease
#out of 207 males: 93 have heart disease & 114 do not have heart disease
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='sex',hue='target',data=df)
plt.show()

#in foll. graph out of 96 are females:24 do not have disease & 72 have disease
#out of 207 males: 114 do not have & 93 have disease

# %%
ax=sns.catplot(x='target',col='sex',data=df,kind='count',height=5,aspect=1)

# %%
# Plot bars horizontally

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(y='target',hue='sex',data=df)
plt.show()

# %%
#use a different color palette

f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='target',data=df,palette='Set3')
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='target',data=df,facecolor=(0,0,0,0),linewidth=5,edgecolor=sns.color_palette('dark',3))
plt.show()

# %%
df.groupby('fbs')['target'].value_counts()
# Out:
# fbs  target
# 0    1         142
#      0         116
# 1    1          23
#      0          22
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='target',hue='fbs',data=df)
plt.show()

# %%
df.groupby('exang')['target'].value_counts()
# Out:
# exang  target
# 0      1         142
#        0          62
# 1      0          76
#        1          23
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='target',hue='exang',data=df)
plt.show()

# %% [markdown]
# # Univariate Analysis
# - our feature variable of interest is target
# - it is integer valued as 0:absence and 1:presence of heart disease
# - 165 patients are suffering from heart disease & 138 do not have heart disease
# - out of 96 females: 72 have heart disease & 24 do not have
# - out of 207 males: 93 have heart disease & 114 do not have

# %% [markdown]
# # BI-Variate Analysis

# %%
correlation =df.corr()

# %% [markdown]
# - The target variable is target. So, we check how each attribute correlates with target variable

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# # Interpretation of correlation coefficient
# - correlation coefficient ranges from -1 to +1
# - when it is close to +1, there is strong positive correlation
# - when it is close to -1, there is strong negative correlation
# - when it is close to 0, there is no correlation

# %%
#We can see that cp and thalach variables are mildly +vely correlated with target variable.

# %% [markdown]
# # Analysis of target and cp variable

# %% [markdown]
# - CP stands for chest pain type

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].unique()     #categorical variable bcz it contains 4 types of values 0,1,2,3
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
# visualize frequency distribution of cp variable

f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='cp',data=df)
plt.show()

# %%
# frequency distribution of targt w.r.to cp

df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
# we can visualize value counts of cp w.r.t. target

f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x='cp',hue='target',data=df)
plt.show()

# %%
ax=sns.catplot(x='target',col='cp',data=df,kind='count',height=8,aspect=1)

# %% [markdown]
# # Analysis of target and thalach variable
# - thalach stands for maximum heart rate achieved

# %%
df['thalach'].nunique()  #numerical variable bca]z it has 91 unique values
# Out:
# 91

# %%
# Visualize frequency distribution of thalach variable

f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
ax=sns.distplot(x,bins=10)
plt.show()    #Here, we see that thalach variable is slightly negatively skewed

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name='thalach variable')
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name='thalach variable')
ax=sns.distplot(x,bins=10,vertical=True)
plt.show()

# %% [markdown]
# # Seaborn Kernel Density Estimation (KDE) Plot
# - useful tool for plotting shape of distribution
# - It plots density of observations on one axis with height along other axis

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name='thalach variable')
ax=sns.kdeplot(x)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name='thalach variable')
ax=sns.kdeplot(x,shade=True,color='r')
plt.show()

# %% [markdown]
# # Histogram
# - represents distribution of data by forming bins along range of data & then drawing bars to show no. of observations that fall in each bin

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
ax=sns.distplot(x,kde=False,rug=True,bins=10)
plt.show()

# %%
# Visualize frequency distribution of thalach variable with target

f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y='thalach',data=df)
plt.show()

# we can see that people suffering from heart disease have relatively higher heart rate compared to people not suffering from heart disease

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y='thalach',data=df,jitter=0.01)
plt.show()

# %%
# Visualize distribution of thalach variable w.r.t. target

f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x='target',y='thalach',data=df)
plt.show()
#It shows that people suffering from heart disease(target=1) have relatively higher 
#heart rate(thalach) as compared to people not suffering from heart disease(target=0)

# %% [markdown]
# # Heat Map

# %%
plt.figure(figsize=(12,14))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a=sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %% [markdown]
# # From above correlation heat map, we conclude that:
# - target & cp are mildly positively correlated(correlation coefficient:0.43)
# - target & thalach are also mildly positively correlated(correlation coefficient:0.42)
# - target & slope are weakly positively correlated(correlation coefficient:0.35)
# - target & exang are mildly negatively correlated(correlation coefficient:-0.44)
# - target & oldpeak are mildly negatively correlated(correlation coefficient:-0.43)
# - target & ca are weakly negatively correlated(correlation coefficient:-0.39)
# - target & thal are also weakly negatively correlated(correlation coefficient:-0.34)

# %%
num_var=['age','trestbps','chol','thalach','oldpeak','target']
sns.pairplot(df[num_var],kind='scatter', diag_kind='hist')
plt.show()

# %%
#we have defined variable num_var.
#Here, age,trestbps,chol,thalach, oldpeak are numerical variables 
#and target is categorical variable

# %%
# Check no. of unique values in age variable
df['age'].nunique()
# Out:
# 41

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
# mean value of age is 54.37 years & min & max values of age are 29 & 77

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['age']
ax=sns.distplot(x,bins=10)
plt.show()

# %%
# Analyze age and target variable

f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y='age',data=df)
plt.show()

# %%
# we can see that people suffering from heart disease(1) and not suffering from heart
# disease(0) have comparable ages

# %%
# visualize age variable w.r.to target with boxplot

f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x='target',y='age',data=df)
plt.show()

# %% [markdown]
# # above boxplot tells 2 different things:
# - mean age of people who have heart disease is less than mean age of people ho do not have heart disease
# - dispersion or spread of age of people who have heart disease is greater than people who do not have

# %%
# Analyze age and trestbps variable

f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x='age',y='trestbps',data=df)
plt.show()

# %% [markdown]
# - above scatterplot shows that there is no correlation between age & trestbps variable

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x='age',y='trestbps',data=df)
plt.show()

# %% [markdown]
# - above line shows that linear regression model is not good fit to data

# %%
# Analyze chol & thalach variable

f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x='chol',y='thalach',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x='chol',y='thalach',data=df)
plt.show()

# %% [markdown]
# - above plot shows that there is no correlation between chol and thalach variable

# %% [markdown]
# # Dealing with missing values
# - in pandas,missing data is represented by two values:
# - None : used for missing data in python code
# - NaN : floating-point value recognized by all systems that use standard IEEE floating-point representation

# %% [markdown]
# # Pandas isnull() and notnull() functions

# %% [markdown]
# Functions to test for missing data-1.isnull() 2.notnull()
# - These are simple functions that return a boolean value indicating whether passed in argument value is in fact missing data

# %% [markdown]
# # Commands to detect missing values
# - df.isnull() : checks whether each cell in dataframe contains missing value or not
# - df.isnull().sum() : Returns total no. of missing values in each column in dataframe
# - df.isnull().sum().sum() : returns total no. of missing values in dataframe
# - df.isnull().mean() : returns percentage of missing values ineach column in dataframe
# - df.isnull().any() : checks which column has null values and which has not.(True and False)
# - df.isnull().any().any() : returns boolean value indicatingg whether dataframe has missing values or not
# - df.isnull().values.any() : it checks whether particular column has missing value or not,returns boolean value
# - df.isnull().values.sum() : returns total no. of missing values in dataframe

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# - There is no missing value in dataset

# %% [markdown]
# # Assert Statement
# - check that no missing,unexpected 0 or negative values are present.
# - It will return nothing if value is being tested is TRUE and will throw an AssertionError if value is False
# - Asserts
# - assert 1 == 1 (return nothing if value is True)
# - assert 1 == 2 (return AssertionError if value is False)

# %%
# asserts that there are no missing values in dataframe

assert pd.notnull(df).all().all()

# %%
# assert all values are greater than or equal to 0

assert(df>=0).all().all()

# %% [markdown]
# - Above 2 commands do not throw any error
# - i.e. there are no missing/negative values in dataset
# - all values are greater than or equal to 0

# %% [markdown]
# # Outlier Detection

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df['age'])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df['trestbps'])
plt.show()

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df['chol'])
plt.show()

# %%
df['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df['thalach'])
plt.show()

# %%
df['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df['oldpeak'])
plt.show()

# %% [markdown]
# - age variable does not contain any outlier
# - trestbps variable contains outliers to right side
# - chol variable also contains outliers to right side
# - thalach variable also contain single outlier to left side
# - oldpeak variable contains outliers to right side
# - These variables containing outliers need further investigation
